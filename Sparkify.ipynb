# %% [markdown]
# # Sparkify Project Workspace
# This workspace contains a tiny subset (128MB) of the full dataset available (12GB). Feel free to use this workspace to build your project, or to explore a smaller subset with Spark before deploying your cluster on the cloud. Instructions for setting up your Spark cluster is included in the last lesson of the Extracurricular Spark Course content.
#
# You can follow the steps below to guide your data analysis and model building portion of this project.

# %%
# import libraries
from pyspark.sql import SparkSession
from pyspark.sql.functions import isnan, count, when, col, desc, udf, col, sort_array, asc, avg
from pyspark.sql.functions import sum as Fsum
from pyspark.sql.window import Window
from pyspark.sql.types import IntegerType
from pyspark.sql import Window

# %%
# create a Spark session
spark = SparkSession \
    .builder \
    .appName("Sparkify") \
    .getOrCreate()

# %% [markdown]
# # Load and Clean Dataset
# In this workspace, the mini-dataset file is `mini_sparkify_event_data.json`. Load and clean the dataset, checking for invalid or missing data - for example, records without userids or sessionids.

# %%
df = spark.read.json("mini_sparkify_event_data.json")

# %%
df.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
user_log_valid = df.dropna(how = "any", subset = ["userId", "sessionId"])

# %%
user_log_valid.count()
# Out:
# 286500

# %%
df.select("userId").dropDuplicates().sort("userId").show()
# Out:
# +------+
# |userId|
# +------+
# |      |
# |    10|
# |   100|
# |100001|
# |100002|
# |100003|
# |100004|
# |100005|
# |100006|
# |100007|
# |100008|
# |100009|
# |100010|
# |100011|
# |100012|
# |100013|
# |100014|
# |100015|
# |100016|
# |100017|
# +------+
# only showing top 20 rows

# %%
user_log_valid = user_log_valid.filter(user_log_valid["userId"] != "")

# %%
user_log_valid.count()
# Out:
# 278154

# %%
#Checking initial 5 rows
user_log_valid.take(5)
# Out:
# [Row(artist='Martha Tilston', auth='Logged In', firstName='Colin', gender='M', itemInSession=50, lastName='Freeman', length=277.89016, level='paid', location='Bakersfield, CA', method='PUT', page='NextSong', registration=1538173362000, sessionId=29, song='Rockpools', status=200, ts=1538352117000, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='30'),
#  Row(artist='Five Iron Frenzy', auth='Logged In', firstName='Micah', gender='M', itemInSession=79, lastName='Long', length=236.09424, level='free', location='Boston-Cambridge-Newton, MA-NH', method='PUT', page='NextSong', registration=1538331630000, sessionId=8, song='Canada', status=200, ts=1538352180000, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"', userId='9'),
#  Row(artist='Adam Lambert', auth='Logged In', firstName='Colin', gender='M', itemInSession=51, lastName='Freeman', length=282.8273, level='paid', location='Bakersfield, CA', method='PUT', page='NextSong', registration=1538173362000, sessionId=29, song='Time For Miracles', status=200, ts=1538352394000, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='30'),
#  Row(artist='Enigma', auth='Logged In', firstName='Micah', gender='M', itemInSession=80, lastName='Long', length=262.71302, level='free', location='Boston-Cambridge-Newton, MA-NH', method='PUT', page='NextSong', registration=1538331630000, sessionId=8, song='Knocking On Forbidden Doors', status=200, ts=1538352416000, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"', userId='9'),
#  Row(artist='Daft Punk', auth='Logged In', firstName='Colin', gender='M', itemInSession=52, lastName='Freeman', length=223.60771, level='paid', location='Bakersfield, CA', method='PUT', page='NextSong', registration=1538173362000, sessionId=29, song='Harder Better Faster Stronger', status=200, ts=1538352676000, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='30')]

# %% [markdown]
# # Exploratory Data Analysis
# When you're working with the full dataset, perform EDA by loading a small subset of the data and doing basic manipulations within Spark. In this workspace, you are already provided a small subset of data you can explore.
#
# ### Define Churn
#
# Once you've done some preliminary analysis, create a column `Churn` to use as the label for your model. I suggest using the `Cancellation Confirmation` events to define your churn, which happen for both paid and free users. As a bonus task, you can also look into the `Downgrade` events.
#
# ### Explore Data
# Once you've defined churn, perform some exploratory data analysis to observe the behavior for users who stayed vs users who churned. You can start by exploring aggregates on these two groups of users, observing how much of a specific action they experienced per a certain time unit or number of songs played.

# %%
user_log_valid.select("page").dropDuplicates().sort("page").show()
# Out:
# +--------------------+
# |                page|
# +--------------------+
# |               About|
# |          Add Friend|
# |     Add to Playlist|
# |              Cancel|
# |Cancellation Conf...|
# |           Downgrade|
# |               Error|
# |                Help|
# |                Home|
# |              Logout|
# |            NextSong|
# |         Roll Advert|
# |       Save Settings|
# |            Settings|
# |    Submit Downgrade|
# |      Submit Upgrade|
# |         Thumbs Down|
# |           Thumbs Up|
# |             Upgrade|
# +--------------------+

# %%
user_log_valid.filter("page = 'Cancellation Confirmation'").show()
# Out:
# +------+---------+---------+------+-------------+---------+------+-----+--------------------+------+--------------------+-------------+---------+----+------+-------------+--------------------+------+
# |artist|     auth|firstName|gender|itemInSession| lastName|length|level|            location|method|                page| registration|sessionId|song|status|           ts|           userAgent|userId|
# +------+---------+---------+------+-------------+---------+------+-----+--------------------+------+--------------------+-------------+---------+----+------+-------------+--------------------+------+
# |  null|Cancelled|   Adriel|     M|          104|  Mendoza|  null| paid|  Kansas City, MO-KS|   GET|Cancellation Conf...|1535623466000|      514|null|   200|1538943990000|"Mozilla/5.0 (Mac...|    18|
# |  null|Cancelled|    Diego|     M|           56|    Mckee|  null| paid|Phoenix-Mesa-Scot...|   GET|Cancellation Conf...|1537167593000|      540|null|   200|1539033046000|"Mozilla/5.0 (iPh...|    32|
# |  null|Cancelled|    Mason|     M|           10|     Hart|  null| free|  Corpus Christi, TX|   GET|Cancellation Conf...|1533157139000|      174|null|   200|1539318918000|"Mozilla/5.0 (Mac...|   125|
# |  null|Cancelled|Alexander|     M|          332|   Garcia|  null| paid|Indianapolis-Carm...|   GET|Cancellation Conf...|1536817381000|      508|null|   200|1539375441000|Mozilla/5.0 (Wind...|   105|
# |  null|Cancelled|    Kayla|     F|          273|  Johnson|  null| paid|Philadelphia-Camd...|   GET|Cancellation Conf...|1538333829000|      797|null|   200|1539465584000|Mozilla/5.0 (Wind...|    17|
# |  null|Cancelled|    Molly|     F|           29| Harrison|  null| free|Virginia Beach-No...|   GET|Cancellation Conf...|1534255113000|      843|null|   200|1539588854000|"Mozilla/5.0 (Mac...|   143|
# |  null|Cancelled|     Alex|     M|          145|    Hogan|  null| paid|Denver-Aurora-Lak...|   GET|Cancellation Conf...|1535066380000|      842|null|   200|1539729037000|Mozilla/5.0 (Wind...|   101|
# |  null|Cancelled|    Davis|     M|           34|     Wang|  null| paid|           Flint, MI|   GET|Cancellation Conf...|1538289776000|      802|null|   200|1539736161000|"Mozilla/5.0 (Win...|   129|
# |  null|Cancelled|  Nikolas|     M|          287|    Olsen|  null| paid|Oxnard-Thousand O...|   GET|Cancellation Conf...|1528403713000|      881|null|   200|1539759749000|Mozilla/5.0 (X11;...|   121|
# |  null|Cancelled|    Ethan|     M|          176|  Johnson|  null| paid|Lexington-Fayette...|   GET|Cancellation Conf...|1538080987000|      934|null|   200|1539761972000|"Mozilla/5.0 (Win...|    51|
# |  null|Cancelled|Christian|     M|          100| Robinson|  null| paid|       Quincy, IL-MO|   GET|Cancellation Conf...|1534942082000|     1092|null|   200|1540050556000|"Mozilla/5.0 (Win...|    87|
# |  null|Cancelled|    Molly|     F|           43|Patterson|  null| paid|   Memphis, TN-MS-AR|   GET|Cancellation Conf...|1535498705000|     1029|null|   200|1540062068000|Mozilla/5.0 (X11;...|   122|
# |  null|Cancelled|   Sophia|     F|           72|    Perry|  null| paid|Los Angeles-Long ...|   GET|Cancellation Conf...|1533885783000|     1072|null|   200|1540193374000|Mozilla/5.0 (Wind...|    12|
# |  null|Cancelled|    Erick|     M|           48|   Brooks|  null| paid|           Selma, AL|   GET|Cancellation Conf...|1537956751000|     1112|null|   200|1540223006000|"Mozilla/5.0 (Win...|    58|
# |  null|Cancelled|   Rachel|     F|           11|   Bailey|  null| paid|Albany-Schenectad...|   GET|Cancellation Conf...|1536102943000|     1059|null|   200|1540402387000|Mozilla/5.0 (Wind...|    73|
# |  null|Cancelled|  Jeffery|     M|           46|  Wheeler|  null| paid|         Bozeman, MT|   GET|Cancellation Conf...|1533886191000|     1324|null|   200|1540875543000|"Mozilla/5.0 (Win...|     3|
# |  null|Cancelled|   Sophia|     F|           18|      Key|  null| paid|Los Angeles-Long ...|   GET|Cancellation Conf...|1537679535000|     1383|null|   200|1541166424000|"Mozilla/5.0 (Mac...|   106|
# |  null|Cancelled|    Piper|     F|            8|  Nielsen|  null| paid|New York-Newark-J...|   GET|Cancellation Conf...|1537699856000|     1583|null|   200|1541340091000|"Mozilla/5.0 (Mac...|   103|
# |  null|Cancelled|   Teagan|     F|          306|  Roberts|  null| paid|New Philadelphia-...|   GET|Cancellation Conf...|1537634865000|     1519|null|   200|1541463632000|Mozilla/5.0 (Wind...|    28|
# |  null|Cancelled|    Alexi|     F|           42|   Warren|  null| paid|Spokane-Spokane V...|   GET|Cancellation Conf...|1532482662000|     1819|null|   200|1542051608000|Mozilla/5.0 (Wind...|    54|
# +------+---------+---------+------+-------------+---------+------+-----+--------------------+------+--------------------+-------------+---------+----+------+-------------+--------------------+------+
# only showing top 20 rows

# %%
flag_downgrade_event = udf(lambda x: 1 if x == "Cancellation Confirmation" else 0, IntegerType())

# %%
user_log_valid = user_log_valid.withColumn("Churn", flag_downgrade_event("page"))

# %%
user_log_valid.head()
# Out:
# Row(artist='Martha Tilston', auth='Logged In', firstName='Colin', gender='M', itemInSession=50, lastName='Freeman', length=277.89016, level='paid', location='Bakersfield, CA', method='PUT', page='NextSong', registration=1538173362000, sessionId=29, song='Rockpools', status=200, ts=1538352117000, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.
, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539041387000, page='NextSong', level='paid', phase=1),
# ...
#  Row(userId='54', firstname='Alexi', ts=1539206044000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539206158000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539206475000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539206695000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539206944000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539207113000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539207351000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539207549000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539207698000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539207892000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539208129000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539208353000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539208354000, page='Thumbs Up', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539208616000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539208917000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539208918000, page='Thumbs Up', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539209146000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539209308000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539209886000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539210083000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539210285000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539210463000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539210515000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539210724000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539210935000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539211087000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539211343000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539211571000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539211855000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539212065000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539212207000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539212429000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539212558000, page='Home', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539212638000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539212889000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539213138000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539213403000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539213575000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539213828000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539214029000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539214480000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539214683000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539214847000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539215034000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539215080000, page='Downgrade', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539215257000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539215464000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539215718000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539216081000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539216286000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539216287000, page='Thumbs Up', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539216506000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539216726000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539216953000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539217155000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539217432000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539217690000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539217895000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539218124000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539218363000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539218580000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539218764000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539218971000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539219149000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539219168000, page='Add to Playlist', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539219520000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539219679000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539219916000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539220223000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539220470000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539220683000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539220920000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539220921000, page='Thumbs Up', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539221149000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539221458000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539221708000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539221923000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539221924000, page='Thumbs Up', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539222219000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539222439000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539222828000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539223312000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539223516000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539223540000, page='Home', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539223924000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539224191000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539224846000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539225090000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539225109000, page='Home', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539225316000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539225484000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539225729000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539226033000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539226509000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539226704000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539226982000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539227044000, page='Add to Playlist', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539227245000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539227452000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539227634000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539227775000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539227988000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539228285000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539228594000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539228674000, page='Add to Playlist', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539228812000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539228813000, page='Thumbs Up', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539229052000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539229369000, page='Home', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539229382000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539229591000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539230132000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539230673000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539230806000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539231051000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539231283000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539231710000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539231901000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539231902000, page='Thumbs Up', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539232140000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539232373000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539232590000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539232778000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539233006000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539233318000, page='Add to Playlist', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539233454000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539233468000, page='Add to Playlist', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539233674000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539234001000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539234117000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539234164000, page='Downgrade', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539234279000, page='Home', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539234329000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539234330000, page='Logout', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539234535000, page='Home', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539234582000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539234775000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539235184000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539235337000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539235491000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539235537000, page='Add to Playlist', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539235613000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539235895000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539236092000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539236093000, page='Add Friend', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539236293000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539236531000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539236732000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539236843000, page='Add to Playlist', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539236986000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539236987000, page='Thumbs Up', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539237028000, page='Add to Playlist', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539237154000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539237422000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539237631000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539237915000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539238079000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539238285000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539238531000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539238649000, page='Add to Playlist', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539238742000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539238930000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539239121000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539239339000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539239557000, page='NextSong', level='paid', phase=1),
#  Row(userId='54', firstname='Alexi', ts=1539239558000, page='Thumbs Down', level='paid', phase=1),
#  ...]

# %% [markdown]
# # Feature Engineering
# Once you've familiarized yourself with the data, build out the features you find promising to train your model on. To work with the full dataset, you can follow the following steps.
# - Write a script to extract the necessary features from the smaller subset of data
# - Ensure that your script is scalable, using the best practices discussed in Lesson 3
# - Try your script on the full data set, debugging your script if necessary
#
# If you are working in the classroom workspace, you can just extract features based on the small subset of data contained here. Be sure to transfer over this work to the larger dataset when you work on your Spark cluster.

# %% [markdown]
# # Modeling
# Split the full dataset into train, test, and validation sets. Test out several of the machine learning methods you learned. Evaluate the accuracy of the various models, tuning parameters as necessary. Determine your winning model based on test accuracy and report results on the validation set. Since the churned users are a fairly small subset, I suggest using F1 score as the metric to optimize.

# %% [markdown]
# # Final Steps
# Clean up your code, adding comments and renaming variables to make the code easier to read and maintain. Refer to the Spark Project Overview page and Data Scientist Capstone Project Rubric to make sure you are including all components of the capstone project and meet all expectations. Remember, this includes thorough documentation in a README file in a Github repository, as well as a web app or blog post.
